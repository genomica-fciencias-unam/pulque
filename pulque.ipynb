# %%
library(phyloseq)
library(ggplot2)
library(vegan)
library(phyloseq)
library (ape)
packageVersion("phyloseq")
source("read.newick.R")
library(dplyr)
biom_otu_tax <- import_biom("bact_cdhit_otus.biom", parseFunction=parse_taxonomy_greengenes)
# import_biom("path-to-file.biom", parseFunction=parse_taxonomy_greengenes)
biom_otu_tax
sample_names(biom_otu_tax)
data= read.table("metadata", header=T, row.names=1, sep="\t")
#t(head(otu_table(biom_otu_tax))) para ver el orden de los datos
sampledata = sample_data(data.frame(id=data$id, sample_type=data$sample_type, row.names=sample_names(biom_otu_tax)))
pulque <- phyloseq(otu_table(biom_otu_tax), tax_table(biom_otu_tax), sampledata)
pulque

# ?write.csv
write.csv(otu_table(biom_otu_tax), "otutable.txt")
write.csv(tax_table(biom_otu_tax), "taxtable.txt")
tax_table(biom_otu_tax)
# Out:
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.5-4
# [1] ‘1.26.1’
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 5573 taxa and 24 samples ]
# tax_table()   Taxonomy Table:    [ 5573 taxa by 7 taxonomic ranks ]
#  [1] " amiel1"       " amiel1subs2"  " amiel1subs3"  " amiel2"
#  [5] " amiel2subs1"  " amiel2subs2"  " amiel2subs3"  " cpunta1"
#  [9] " cpunta1subs2" " cpunta1subs3" " cpunta2"      " cpunta2subs2"
# [13] " cpunta2subs3" " pulque1"      " pulque1subs1" " pulque1subs2"
# [17] " pulque1subs3" " pulque2"      " pulque2subs1" " pulque2subs2"
# [21] " amiel1subs1"  " pulque2subs3" " cpunta1subs1" " cpunta2subs1"
# phyloseq-class experiment-level object
# ...

# %%
p <- plot_richness(pulque, x="sample_type", color="sample_type", measures=c("Observed", "Chao1", "Shannon", "Simpson")) + geom_boxplot()+theme_light() + theme(axis.text.x=element_text(angle=90, hjust=1))
#p$data
a <-p$data
summary(a)
p
# Out:
#            id     sample_type   samples              variable
#  amiel1     : 4   amiel :32   Length:96          Observed:24
#  amiel1subs1: 4   cpunta:32   Class :character   Chao1   :24
#  amiel1subs2: 4   pulque:32   Mode  :character   Shannon :24
#  amiel1subs3: 4                                  Simpson :24
#  amiel2     : 4
#  amiel2subs1: 4
#  (Other)    :72
#      value                 se
#  Min.   :    0.319   Min.   : 490.6
#  1st Qu.:    1.181   1st Qu.: 641.4
#  Median :  257.849   Median : 877.0
#  Mean   : 1599.133   Mean   : 853.0
#  3rd Qu.: 1803.796   3rd Qu.:1016.8
#  Max.   :10607.042   Max.   :1271.9
#                      NA's   :72
# Warning message:
# “Removed 72 rows containing missing values (geom_errorbar).”
# plot without title

# %%
samples_to_keep <- c(" amiel1", " amiel2", " pulque1", " pulque2", " cpunta1", " cpunta2")

# ?subset_samples
# pulque3 <- subset_samples(pulque, samples_to_keep)
# # pulque3 <- prune_samples(samples_to_keep)

pulque2 <- prune_samples(samples_to_keep
              , pulque
             )
sample_names(pulque2)
plot_richness(pulque2, x="sample_type", color="sample_type", measures=c("Observed", "Chao1", "Shannon", "Simpson")) + geom_boxplot()+theme_light() + theme(axis.text.x=element_text(angle=90, hjust=1))
# Out:
# [1] " amiel1"  " amiel2"  " cpunta1" " cpunta2" " pulque1" " pulque2"
# Warning message:
# “Removed 18 rows containing missing values (geom_errorbar).”
# plot without title

# %%
p <- plot_richness(pulque2, x="sample_type", color="sample_type", measures=c("Observed", "Chao1", "Shannon", "Simpson")) + geom_boxplot()+theme_light() + theme(axis.text.x=element_text(angle=90, hjust=1))
#p$data
a <-p$data
a
summary(a)
p
# Out:
#    id      sample_type samples  variable value        se
# 1  amiel1  amiel        amiel1  Observed 1.326000e+03        NA
# 2  amiel2  amiel        amiel2  Observed 1.351000e+03        NA
# 3  cpunta1 cpunta       cpunta1 Observed 1.031000e+03        NA
# 4  cpunta2 cpunta       cpunta2 Observed 1.019000e+03        NA
# 5  pulque1 pulque       pulque1 Observed 9.850000e+02        NA
# 6  pulque2 pulque       pulque2 Observed 1.124000e+03        NA
# 7  amiel1  amiel        amiel1  Chao1    9.503040e+03 1062.7383
# 8  amiel2  amiel        amiel2  Chao1    1.060704e+04 1216.3935
# 9  cpunta1 cpunta       cpunta1 Chao1    6.089764e+03  689.6073
# 10 cpunta2 cpunta       cpunta2 Chao1    5.633513e+03  618.7649
# 11 pulque1 pulque       pulque1 Chao1    7.084125e+03  915.7789
# 12 pulque2 pulque       pulque2 Chao1    9.533554e+03 1241.1103
# 13 amiel1  amiel        amiel1  Shannon  1.676105e+00        NA
# 14 amiel2  amiel        amiel2  Shannon  1.309561e+00        NA
# ...

# %%
# #Datos Carolina
# library(phyloseq)
# library(ggplot2)
# library(vegan)
# library(phyloseq)
# library (ape)
# packageVersion("phyloseq")
# source("read.newick.R")

# biom_otu_tax2 <- import_biom("blast_otus.biom", parseFunction=parse_taxonomy_greengenes)
# # import_biom("path-to-file.biom", parseFunction=parse_taxonomy_greengenes)
# biom_otu_tax2
# sample_names(biom_otu_tax2)
# data= read.table("metadata", header=T, row.names=1, sep="\t")
# #t(head(otu_table(biom_otu_tax))) para ver el orden de los datos
# sampledata = sample_data(data.frame(id=data$id, sample_type=data$sample_type, row.names=sample_names(biom_otu_tax2)))
# pulque2 <- phyloseq(otu_table(biom_otu_tax2), tax_table(biom_otu_tax2), sampledata)
# pulque2


# p <- plot_richness(pulque2, x="sample_type", color="sample_type", measures=c("Observed", "Chao1", "Shannon", "Simpson")) + geom_boxplot()+theme_light() + theme(axis.text.x=element_text(angle=90, hjust=1))
# #p$data
# a <-p$data
# summary(a)
# p

# %%
# biom_otu_tax2 <- import_biom("blast_otuswosingletons.biom", parseFunction=parse_taxonomy_greengenes)
# # import_biom("path-to-file.biom", parseFunction=parse_taxonomy_greengenes)
# biom_otu_tax2
# sample_names(biom_otu_tax2)
# data= read.table("metadata", header=T, row.names=1, sep="\t")
# #t(head(otu_table(biom_otu_tax))) para ver el orden de los datos
# sampledata = sample_data(data.frame(id=data$id, sample_type=data$sample_type, row.names=sample_names(biom_otu_tax2)))
# pulque2 <- phyloseq(otu_table(biom_otu_tax2), tax_table(biom_otu_tax2), sampledata)
# pulque2


# p <- plot_richness(pulque2, x="sample_type", color="sample_type", measures=c("Observed", "Chao1", "Shannon", "Simpson")) + geom_boxplot()+theme_light() + theme(axis.text.x=element_text(angle=90, hjust=1))
# #p$data
# a <-p$data
# summary(a)
# p

# %%
biom_otu_tax2 <- import_biom("bact_cdhit_otuswosingletons.biom", parseFunction=parse_taxonomy_greengenes)
# import_biom("path-to-file.biom", parseFunction=parse_taxonomy_greengenes)
biom_otu_tax2
sample_names(biom_otu_tax2)
data= read.table("metadata", header=T, row.names=1, sep="\t")
#t(head(otu_table(biom_otu_tax))) para ver el orden de los datos
sampledata = sample_data(data.frame(id=data$id, sample_type=data$sample_type, row.names=sample_names(biom_otu_tax2)))
pulque2 <- phyloseq(otu_table(biom_otu_tax2), tax_table(biom_otu_tax2), sampledata)
pulque2


p <- plot_richness(pulque2, x="sample_type", color="sample_type", measures=c("Observed", "Chao1", "Shannon", "Simpson")) + geom_boxplot()+theme_light() + theme(axis.text.x=element_text(angle=90, hjust=1))
#p$data
a <-p$data
summary(a)
p
# Out:
# Warning message in strsplit(conditionMessage(e), "\n"):
# “input string 1 is invalid in this locale”
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 2855 taxa and 24 samples ]
# tax_table()   Taxonomy Table:    [ 2855 taxa by 7 taxonomic ranks ]
#  [1] " amiel1"       " amiel1subs2"  " amiel1subs3"  " amiel2"
#  [5] " amiel2subs1"  " amiel2subs2"  " amiel2subs3"  " cpunta1"
#  [9] " cpunta1subs2" " cpunta1subs3" " cpunta2"      " cpunta2subs2"
# [13] " cpunta2subs3" " pulque1"      " pulque1subs1" " pulque1subs2"
# [17] " pulque1subs3" " pulque2"      " pulque2subs1" " pulque2subs2"
# [21] " amiel1subs1"  " pulque2subs3" " cpunta1subs1" " cpunta2subs1"
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 2855 taxa and 24 samples ]
# sample_data() Sample Data:       [ 24 samples by 2 sample variables ]
# tax_table()   Taxonomy Table:    [ 2855 taxa by 7 taxonomic ranks ]
# ...

# %%
rarecurve(t(otu_table(biom_otu_tax2)), step=100, label=T, col="blue")
# Out:
# plot without title

# %%
library(RColorBrewer)


phylum <- read.table("phyla.txt", header=T, row.names=1)
abund_table <- t(phylum)
x <- abund_table[,order(colSums(abund_table), decreasing=T)]

for (i in 1:dim(x)[2]){
tmp <- data.frame(row.names=NULL,Sample=rownames(x),Taxa=rep(colnames(x)[i],dim(x)[1]),Value=x[,i])
if(i==1){df<-tmp} else {df<-rbind(df,tmp)}
}

df$V1 <- factor(df$Sample, levels=(unique(rownames(x))))
N <- length(df$Taxa)

df$orden <- factor(df$Sample, levels = c("amiel1","amiel1subs1","amiel1subs2","amiel1subs3","amiel2","amiel2subs1","amiel2subs2",
                                         "amiel2subs3","cpunta1", "cpunta1subs1","cpunta1subs2","cpunta1subs3","cpunta2","cpunta2subs1","cpunta2subs2",
                                        "cpunta2subs3","pulque1","pulque1subs1",
                                         "pulque1subs2","pulque1subs3","pulque2","pulque2subs1","pulque2subs2","pulque2subs3"))

p <- ggplot (df, aes(x=df$orden, Value, fill=Taxa)) + geom_bar(stat="identity")
p2 <- p + scale_fill_manual(values=rev(colorRampPalette(brewer.pal(12, "Paired"))(11))) #la última parte, el 12 es definido por la paleta, 23 es el número de categorías (phyla a colorear) pueden poner menos y les va a salir una advertencia de que necesitan definir un mínimo. 
p2 <- p2 +theme_bw() +theme(axis.text.x=element_text(angle=90, hjust=1, vjust=0.5)) 
p2 <- p2 + xlab("") + ylab("Relative Frequency") 
p2
# Out:
# plot without title

# %%
phylum <- read.table("class_bacteria.txt", header=T, row.names=1)
abund_table <- t(phylum)
x <- abund_table[,order(colSums(abund_table), decreasing=T)]

for (i in 1:dim(x)[2]){
tmp <- data.frame(row.names=NULL,Sample=rownames(x),Taxa=rep(colnames(x)[i],dim(x)[1]),Value=x[,i])
if(i==1){df<-tmp} else {df<-rbind(df,tmp)}
}

df$V1 <- factor(df$Sample, levels=(unique(rownames(x))))
N <- length(df$Taxa)

df$orden <- factor(df$Sample, levels = c("amiel1","amiel1subs1","amiel1subs2","amiel1subs3","amiel2","amiel2subs1","amiel2subs2",
                                         "amiel2subs3","cpunta1", "cpunta1subs1","cpunta1subs2","cpunta1subs3","cpunta2","cpunta2subs1","cpunta2subs2",
                                        "cpunta2subs3","pulque1","pulque1subs1",
                                         "pulque1subs2","pulque1subs3","pulque2","pulque2subs1","pulque2subs2","pulque2subs3"))

p <- ggplot (df, aes(x=df$orden, Value, fill=Taxa)) + geom_bar(stat="identity")
p2 <- p + scale_fill_manual(values=rev(colorRampPalette(brewer.pal(12, "Paired"))(31))) #la última parte, el 12 es definido por la paleta, 23 es el número de categorías (phyla a colorear) pueden poner menos y les va a salir una advertencia de que necesitan definir un mínimo. 
p2 <- p2 +theme_bw() +theme(axis.text.x=element_text(angle=90, hjust=1, vjust=0.5)) 
p2 <- p2 + xlab("") + ylab("Relative Frequency") 
p2
ggsave("bar_class.pdf", width=60, height=20, units="cm")
# Out:
# plot without title

# %%
GP1 <- pulque2 

    tax_table(GP1) <- tax_table(GP1)[,1:6] #dejar sin especies la tabla
    x2 <- tax_glom(GP1, taxrank="Genus")
    

    phylum.sum = tapply(taxa_sums(x2), tax_table(x2)[, "Genus"], sum, na.rm = FALSE)
    top15phyla = names(sort(phylum.sum, TRUE))[1:22]
    gp1 = prune_taxa((tax_table(x2)[, "Genus"] %in% top15phyla), x2)    
    gp1 = transform_sample_counts(gp1, function(OTU) OTU/sum(OTU))
    gp1 <- phyloseq(otu_table(gp1), tax_table(pulque2), sampledata)
   
    plot_heatmap(x2,"Jaccard", "bray", "sample_type", "Genus", low="#bebebe", high="#000000", na.value="white")
    mergeph1 = merge_samples(x2, "sample_type")
    mergeph1   
 plot_heatmap(mergeph1,"Jaccard", "bray", "sample_type", "Genus", low="#bebebe", high="#000000", na.value="white")
        
    plot_bar(gp1, fill="Genus") +  scale_fill_manual(values=rev(colorRampPalette(brewer.pal(12, "Paired"))(27))) +theme_bw() +theme(axis.text.x=element_text(angle=90, hjust=1, vjust=0.5))
    
    
gp1.proteo = subset_taxa(GP1, Phylum=="Proteobacteria")

 
    tax_table(gp1.proteo) <- tax_table(gp1.proteo)[,1:6] #dejar sin especies la tabla
    x3 <- tax_glom(gp1.proteo, taxrank="Genus")
    x3 = transform_sample_counts(x3, function(x) x/sum(x))
    x3 <- phyloseq(otu_table(x3), tax_table(gp1.proteo), sampledata)
    
    
    phylum.sum = tapply(taxa_sums(x3), tax_table(x3)[, "Genus"], sum, na.rm = TRUE)
    top15phyla = names(sort(phylum.sum, TRUE))[1:15]
    gp1 = prune_taxa((tax_table(x3)[, "Genus"] %in% top15phyla), x3)
    plot_bar(gp1, fill="Genus") +  scale_fill_manual(values=rev(colorRampPalette(brewer.pal(12, "Paired"))(23)))+theme_bw() +theme(axis.text.x=element_text(angle=90, hjust=1, vjust=0.5))
# Out:
# Warning message in plot_heatmap(x2, "Jaccard", "bray", "sample_type", "Genus", low = "#bebebe", :
# “Attempt to access ordination coordinates for sample ordering failed.
# Using default sample ordering.”Warning message in plot_heatmap(x2, "Jaccard", "bray", "sample_type", "Genus", low = "#bebebe", :
# “Attempt to access ordination coordinates for feature/species/taxa/OTU ordering failed.
# Using default feature/species/taxa/OTU ordering.”Warning message:
# “Transformation introduced infinite values in discrete y-axis”
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 57 taxa and 3 samples ]
# sample_data() Sample Data:       [ 3 samples by 2 sample variables ]
# tax_table()   Taxonomy Table:    [ 57 taxa by 6 taxonomic ranks ]
# Warning message in plot_heatmap(mergeph1, "Jaccard", "bray", "sample_type", "Genus", :
# “Attempt to access ordination coordinates for sample ordering failed.
# ...

# %%
GP1 <- pulque2 

    tax_table(GP1) <- tax_table(GP1)[,1:6] #dejar sin especies la tabla
    x2 <- tax_glom(GP1, taxrank="Genus")
    

   
    mergeph1 = merge_samples(x2, "sample_type")
#     mergeph1 = transform_sample_counts(mergeph1,function(x) (x/sum(x)))                            
    mergeph1   
                                  
#  plot_heatmap(mergeph1,"Jaccard", "bray", "sample_type", "Genus", low="#bebebe", high="#000000", na.value="white")
        
       #Correción a valores vacios en Género 
    
ylabvec = as(tax_table(mergeph1)[,"Genus"], "character")
names(ylabvec) <- taxa_names(mergeph1)
ylabvec[is.na(ylabvec)] <- ""
                                                                                                      
    t1 <- as.data.frame(colSums(otu_table(mergeph1))) #para ordenar x abundancia
head(t1)
 
t <-(tax_table(mergeph1)) #hago esto porque el melt sobre este objeto phyloseq no trabaja, creo que hay que usar psmelt para esto
# write.table(t, "vennupset.txt")
                                       
                                       
write.csv(t(otu_table(mergeph1)), "tmp_bactotu.txt")
write.csv((tax_table(mergeph1)), "tmp_bacttax.txt")
                                       
# t <- as.data.frame(read.table("taxvennupset.txt", header=T, row.names = 1))

# system("paste vennupset.txt taxvennupset.txt >coreupset.txt")

# read.table("coreupset.txt", header=T, sep="\t") 
t3 <- merge(t,t1, by=0, all=TRUE )
head(t3)
names(t3)[8] <-"abundance"

t4 <- t3[order(-t3$abundance),]
write.table(t4, "taxvennupset-lineas.txt")
 t5 <-   as.vector(t4$Row.names)
# t5
summary(t4)

plot_heatmap(mergeph1, NULL, taxa.order=rev(t5)) + scale_y_discrete(labels=ylabvec)  + theme_minimal () +
   scale_fill_gradient(low="#bebebe", high="#000000", na.value = "white", trans = "log2")  +
   theme(axis.text.x = element_text( angle = 90, hjust = 1),
         axis.text.y = element_text(size = 5))

 ggsave("pulque_bact_heatmap.pdf", width=21, height=27, units="cm")
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 57 taxa and 3 samples ]
# sample_data() Sample Data:       [ 3 samples by 2 sample variables ]
# tax_table()   Taxonomy Table:    [ 57 taxa by 6 taxonomic ranks ]
#     colSums(otu_table(mergeph1))
# 101   9603
# 284      7
# 286  38331
# 297      5
# 298      3
# 312 228685
#   Row.names Kingdom  Phylum         Class               Order
# 1 101       Bacteria Firmicutes     Bacilli             Lactobacillales
# 2 1110      Bacteria Firmicutes     Bacilli             Lactobacillales
# 3 1177      Bacteria Proteobacteria Alphaproteobacteria Sphingomonadales
# 4 1238      Bacteria Proteobacteria Alphaproteobacteria Rhodobacterales
# 5 1692      Bacteria Proteobacteria Alphaproteobacteria Sphingomonadales
# 6 2019      Bacteria Proteobacteria Gammaproteobacteria Enterobacteriales
#   Family             Genus         colSums(otu_table(mergeph1))
# 1 Lactobacillaceae   Lactobacillus 9603
# ...

# %%
#para hacer el càlculo se obtienen las listas de OTUs por cada condición a comparar, luego usamos http://bioinformatics.psb.ugent.be/cgi-bin/liste/Venn/calculate_venn.htpl para armar los diagramas de Venn y las listas resultantes. 
merge1 = merge_samples(pulque2, "sample_type")
write.table(t(otu_table(merge1)), "tmp")
df <-read.table("tmp", header=T, row.names = 1)
k <- which(df>=1, arr.ind=TRUE)
df[k] <- rownames(k)

write.table(df,"Venn_input.txt")
for (ci in 1:ncol(df)) {
    write.csv(df[,ci], paste("col", ci, ".tsv", sep = ""))
}

#cortar columnas 2 y 3, quitar 0s de Venn_input.txt 
#awk '{print $2"\t"$3}' Venn_input.txt | perl -pe 's/\"0\"//g;s/\"//g'

# %%
#hacer un heatmap solo con los OTUs core...(del punto anterior)
#este color picker está fantástico https://www.w3schools.com/colors/colors_picker.asp?color=80ced6

physeqsubsetOTU <- subset_taxa(pulque2, rownames(tax_table(pulque2)) %in% c("512", "722", "2154", "742", "101", "2460", "2114", "2045", "1877", "536", "508", "39", "678", "51", "545", "526", "566", "3170", "659", "425", "57", "89", "649", "2150", "2019", "3472", "2041", "1101", "681", "890", "1350", "563", "2919", "928", "36", "546", "729", "80", "92", "2253", "419", "2015", "290", "2021", "2038", "570", "2048", "13", "597", "2307", "488", "2189", "644", "525", "787", "650", "426", "372", "1053", "414", "615", "2246", "2888", "3850", "795", "679", "1147", "905", "1097", "616", "6", "562", "65", "1093", "547", "807", "560", "1408", "2144", "76", "236", "98", "43", "2582", "288", "586", "1185", "417", "22", "3296", "2220", "2174", "519", "333", "2210", "446", "2337", "7", "556", "663", "946", "3190", "434", "2156", "811", "754", "2317", "230", "2050", "612", "503", "667", "5016", "980", "2097", "66", "1016", "1065", "3503", "2466", "783", "49", "2046", "715", "23", "460", "1035", "897", "312", "286", "235", "2244", "445", "590", "500", "1326", "1005", "16", "489", "585", "622", "2381", "521", "103", "2039", "497", "231", "504", "707", "420", "639", "216", "306", "2225", "30", "3304", "3567"))
physeqsubsetOTU
plot_heatmap(physeqsubsetOTU,"Jaccard", "bray", "sample_type", "Genus",low="#bebebe", high="#000000", na.value="white")
physeqsubsetGenus <- subset_taxa(x2, rownames(tax_table(x2)) %in% c("512", "722", "2154", "742", "101", "2460", "2114", "2045", "1877", "536", "508", "39", "678", "51", "545", "526", "566", "3170", "659", "425", "57", "89", "649", "2150", "2019", "3472", "2041", "1101", "681", "890", "1350", "563", "2919", "928", "36", "546", "729", "80", "92", "2253", "419", "2015", "290", "2021", "2038", "570", "2048", "13", "597", "2307", "488", "2189", "644", "525", "787", "650", "426", "372", "1053", "414", "615", "2246", "2888", "3850", "795", "679", "1147", "905", "1097", "616", "6", "562", "65", "1093", "547", "807", "560", "1408", "2144", "76", "236", "98", "43", "2582", "288", "586", "1185", "417", "22", "3296", "2220", "2174", "519", "333", "2210", "446", "2337", "7", "556", "663", "946", "3190", "434", "2156", "811", "754", "2317", "230", "2050", "612", "503", "667", "5016", "980", "2097", "66", "1016", "1065", "3503", "2466", "783", "49", "2046", "715", "23", "460", "1035", "897", "312", "286", "235", "2244", "445", "590", "500", "1326", "1005", "16", "489", "585", "622", "2381", "521", "103", "2039", "497", "231", "504", "707", "420", "639", "216", "306", "2225", "30", "3304", "3567"))
physeqsubsetGenus  
plot_heatmap(physeqsubsetGenus,"Jaccard", "bray", "sample_type", "Genus", low="#bebebe", high="#000000", na.value="white")
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [
taxa and 3 samples ]
# sample_data() Sample Data:       [ 3 samples by 2 sample variables ]
# tax_table()   Taxonomy Table:    [ 23 taxa by 6 taxonomic ranks ]
# Warning message in plot_heatmap(mergeph1, "Jaccard", "bray", "sample_type", "Genus", :
# “Attempt to access ordination coordinates for sample ordering failed.
# ...

# %%
pulqueCAP.ORD <- ordinate(pulque2, "CAP", "bray", ~ sample_type)
pulqueCAP.ORD

cap_plot <- plot_ordination(pulque2, pulqueCAP.ORD, color="sample_type", axes =c(1,2)) + geom_point(aes(colour = sample_type), alpha=0.4, size=4) + geom_point(colour = "grey90", size=1.5) + theme_bw()

arrowmat <- vegan::scores(pulqueCAP.ORD, display="bp")
arrowdf <- data.frame(labels=rownames(arrowmat), arrowmat)

# Define the arrow aesthetic mapping
arrow_map <- aes(xend = CAP1, 
    yend = CAP2, 
    x = 0, 
    y = 0, 
    shape = NULL, 
    color = NULL, 
    label = labels)

label_map <- aes(x = 1.3 * CAP1, 
    y = 1.3 * CAP2, 
    shape = NULL, 
    color = NULL, 
    label = labels)

arrowhead = arrow(length = unit(0.02, "npc"))

cap_plot  + 
  geom_segment(
    mapping = arrow_map, 
    size = .5, 
    data = arrowdf, 
    color = "gray", 
    arrow = arrowhead
  ) + 
  geom_text(
    mapping = label_map, 
    size = 2,  
    data = arrowdf, 
    show.legend = FALSE
  )

an <- anova(pulqueCAP.ORD, permutations=9999)
an
 ggsave("pulque_bact_ordination.pdf", width=21, height=27, units="cm")
# Out:
# Call: capscale(formula = OTU ~ sample_type, data = data, distance =
# distance)
#
#                Inertia Proportion Rank
# Total          3.07108    1.00000
# Constrained    2.13324    0.69462    2
# Unconstrained  0.97715    0.31818   19
# Imaginary     -0.03931   -0.01280    4
# Inertia is squared Bray distance
# Species scores projected from ‘OTU’
#
# Eigenvalues for constrained axes:
#   CAP1   CAP2
# 2.0669 0.0664
#
# Eigenvalues for unconstrained axes:
#   MDS1   MDS2   MDS3   MDS4   MDS5   MDS6   MDS7   MDS8
# 0.5867 0.2804 0.0413 0.0277 0.0175 0.0128 0.0021 0.0018
# (Showing 8 of 19 unconstrained eigenvalues)
# Warning message:
# “Ignoring unknown aesthetics: label”
#          Df SumOfSqs  F        Pr(>F)
# Model     2 2.1332440 22.92284 1e-04
# Residual 21 0.9771505       NA    NA
# plot without title

# %%
library(DESeq2)
library(phyloseq)
library(plyr)
library(RColorBrewer)

#pulque-cpunta
pulque_sig = pulque
pulque_sig=subset_samples(pulque, sample_type != "amiel")
sample_data(pulque_sig)$var = factor (get_variable(pulque_sig, "sample_type") %in% c("pulque"))
pulque_sig
obj1deseq = phyloseq_to_deseq2(pulque_sig, ~sample_type)


gm_mean = function(x, na.rm=TRUE){
  exp(sum(log(x[x > 0]), na.rm=na.rm) / length(x))
}

geoMeans = apply(counts(obj1deseq), 1, gm_mean)
obj1deseq = estimateSizeFactors(obj1deseq, geoMeans = geoMeans)

##adición de la viñeta para el error de la media de 0s
obj1deseq = DESeq(obj1deseq, fitType="local")


res = results(obj1deseq, cooksCutoff = FALSE)
# quick explanation of Cook's distance: it measures within each gene, for each sample, how removing that sample would change the LFCs (all of the coefficients implied by the design and estimated by DESeq2). So if you have e.g. 3 samples vs 2 samples, and the counts for a gene are [10,10,10] vs [15, 1000], you can see how the Cook's distance will be high for the two samples. Removing either one changes the LFC for the comparison of the two groups. However, if it were [10,10,10] vs [50,50], the two samples "support" each other, such that removing one doesn't change the LFC at all. Hence, we find Cook's to be useful for identifying outliers.
alpha = 0.0001
sigtab = res[which(res$padj < alpha), ]
sigtab = cbind(as(sigtab, "data.frame"), as(tax_table(pulque_sig)[rownames(sigtab), ], "matrix"))
# Phylum order
x = tapply(sigtab$log2FoldChange, sigtab$Phylum, function(x) max(x))
x = sort(x, TRUE)
sigtab$Phylum = factor(as.character(sigtab$Phylum), levels=names(x))
# Genus order
x = tapply(sigtab$log2FoldChange, sigtab$Genus, function(x) max(x))
x = sort(x, TRUE)
sigtab$Genus = factor(as.character(sigtab$Genus), levels=names(x))

ggplot(sigtab, aes(x=Genus, y=log2FoldChange, color=Order)) + scale_color_manual(values=colorRampPalette(brewer.pal(8,"Dark2"))(20))+geom_point(size=3)+theme_light() +theme(axis.text.x = element_text(angle = -90, hjust = 0, vjust=0.5))
#sigtab
#ggsave ("torniquete_pasamanos_SIG.pdf", width=30, height=15, units="cm")
  write.table(sigtab,"bact_pulque-cpuntaOR.csv")
for (ci in 1:ncol(df)) {
    write.csv(df[,ci], paste("col", ci, ".tsv", sep = ""))
}
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 5573 taxa and 16 samples ]
# sample_data() Sample Data:       [ 16 samples by 3 sample variables ]
# tax_table()   Taxonomy Table:    [ 5573 taxa by 7 taxonomic ranks ]
# converting counts to integer mode
# using pre-existing size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# plot without title

# %%
#pulque-aguamiel
pulque_sig = pulque
pulque_sig=subset_samples(pulque, sample_type != "cpunta")
sample_data(pulque_sig)$var = factor (get_variable(pulque_sig, "sample_type") %in% c("pulque"))
pulque_sig
obj1deseq = phyloseq_to_deseq2(pulque_sig, ~sample_type)


gm_mean = function(x, na.rm=TRUE){
  exp(sum(log(x[x > 0]), na.rm=na.rm) / length(x))
}

geoMeans = apply(counts(obj1deseq), 1, gm_mean)
obj1deseq = estimateSizeFactors(obj1deseq, geoMeans = geoMeans)

##adición de la viñeta para el error de la media de 0s
obj1deseq = DESeq(obj1deseq, fitType="local")


res = results(obj1deseq, cooksCutoff = FALSE)
# quick explanation of Cook's distance: it measures within each gene, for each sample, how removing that sample would change the LFCs (all of the coefficients implied by the design and estimated by DESeq2). So if you have e.g. 3 samples vs 2 samples, and the counts for a gene are [10,10,10] vs [15, 1000], you can see how the Cook's distance will be high for the two samples. Removing either one changes the LFC for the comparison of the two groups. However, if it were [10,10,10] vs [50,50], the two samples "support" each other, such that removing one doesn't change the LFC at all. Hence, we find Cook's to be useful for identifying outliers.
alpha = 0.0001
sigtab = res[which(res$padj < alpha), ]
sigtab = cbind(as(sigtab, "data.frame"), as(tax_table(pulque_sig)[rownames(sigtab), ], "matrix"))
# Phylum order
x = tapply(sigtab$log2FoldChange, sigtab$Phylum, function(x) max(x))
x = sort(x, TRUE)
sigtab$Phylum = factor(as.character(sigtab$Phylum), levels=names(x))
# Genus order
x = tapply(sigtab$log2FoldChange, sigtab$Genus, function(x) max(x))
x = sort(x, TRUE)
sigtab$Genus = factor(as.character(sigtab$Genus), levels=names(x))

ggplot(sigtab, aes(x=Genus, y=log2FoldChange, color=Order)) + scale_color_manual(values=colorRampPalette(brewer.pal(8,"Dark2"))(20))+geom_point(size=3)+theme_light() +theme(axis.text.x = element_text(angle = -90, hjust = 0, vjust=0.5))
#sigtab
#ggsave ("torniquete_pasamanos_SIG.pdf", width=30, height=15, units="cm")
  write.table(sigtab,"bact_pulque-amiel_OR.csv")
for (ci in 1:ncol(df)) {
    write.csv(df[,ci], paste("col", ci, ".tsv", sep = ""))
}
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 5573 taxa and 16 samples ]
# sample_data() Sample Data:       [ 16 samples by 3 sample variables ]
# tax_table()   Taxonomy Table:    [ 5573 taxa by 7 taxonomic ranks ]
# converting counts to integer mode
# using pre-existing size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# plot without title

# %%
#amiel-cpunta
pulque_sig = pulque
pulque_sig=subset_samples(pulque, sample_type != "pulque")
sample_data(pulque_sig)$var = factor (get_variable(pulque_sig, "sample_type") %in% c("amiel"))
pulque_sig
obj1deseq = phyloseq_to_deseq2(pulque_sig, ~sample_type)


gm_mean = function(x, na.rm=TRUE){
  exp(sum(log(x[x > 0]), na.rm=na.rm) / length(x))
}

geoMeans = apply(counts(obj1deseq), 1, gm_mean)
obj1deseq = estimateSizeFactors(obj1deseq, geoMeans = geoMeans)

##adición de la viñeta para el error de la media de 0s
obj1deseq = DESeq(obj1deseq, fitType="local")


res = results(obj1deseq, cooksCutoff = FALSE)
# quick explanation of Cook's distance: it measures within each gene, for each sample, how removing that sample would change the LFCs (all of the coefficients implied by the design and estimated by DESeq2). So if you have e.g. 3 samples vs 2 samples, and the counts for a gene are [10,10,10] vs [15, 1000], you can see how the Cook's distance will be high for the two samples. Removing either one changes the LFC for the comparison of the two groups. However, if it were [10,10,10] vs [50,50], the two samples "support" each other, such that removing one doesn't change the LFC at all. Hence, we find Cook's to be useful for identifying outliers.
alpha = 0.0001
sigtab = res[which(res$padj < alpha), ]
sigtab = cbind(as(sigtab, "data.frame"), as(tax_table(pulque_sig)[rownames(sigtab), ], "matrix"))
# Phylum order
x = tapply(sigtab$log2FoldChange, sigtab$Phylum, function(x) max(x))
x = sort(x, TRUE)
sigtab$Phylum = factor(as.character(sigtab$Phylum), levels=names(x))
# Genus order
x = tapply(sigtab$log2FoldChange, sigtab$Genus, function(x) max(x))
x = sort(x, TRUE)
sigtab$Genus = factor(as.character(sigtab$Genus), levels=names(x))

ggplot(sigtab, aes(x=Genus, y=log2FoldChange, color=Order)) + scale_color_manual(values=colorRampPalette(brewer.pal(8,"Dark2"))(30))+geom_point(size=3)+theme_light() +theme(axis.text.x = element_text(angle = -90, hjust = 0, vjust=0.5))
#sigtab
#ggsave ("torniquete_pasamanos_SIG.pdf", width=30, height=15, units="cm")
  write.table(sigtab,"bact_amiel-cpunta_OR.csv")
for (ci in 1:ncol(df)) {
    write.csv(df[,ci], paste("col", ci, ".tsv", sep = ""))
}
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 5573 taxa and 16 samples ]
# sample_data() Sample Data:       [ 16 samples by 3 sample variables ]
# tax_table()   Taxonomy Table:    [ 5573 taxa by 7 taxonomic ranks ]
# converting counts to integer mode
# using pre-existing size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# plot without title
