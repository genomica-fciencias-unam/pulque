# %%
library (phyloseq)
library (ggplot2)
library (vegan)
library (phyloseq)
library (ape)
packageVersion("phyloseq")
source("read.newick.R")
library(dplyr)
# Out:
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.5-4
# [1] ‘1.26.1’
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
biom_otu_tax <- import_biom("its_ene19.biom", parseFunction=parse_taxonomy_greengenes)
# import_biom("path-to-file.biom", parseFunction=parse_taxonomy_greengenes)
biom_otu_tax
sample_names(biom_otu_tax)
data= read.table("metadataits", header=T, row.names=1, sep="\t")
#t(head(otu_table(biom_otu_tax))) #para ver el orden de los datos importante para armar los metadatos que estén en este orden
sampledata = sample_data(data.frame(id=data$id, sample_type=data$sample_type, row.names=sample_names(biom_otu_tax)))
pulque <- phyloseq(otu_table(biom_otu_tax), tax_table(biom_otu_tax), sampledata)
pulque


# ?write.csv
#write.csv(otu_table(biom_otu_tax), "otutable.txt")
#write.csv(tax_table(biom_otu_tax), "taxtable.txt")
#tax_table(biom_otu_tax)
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 1494 taxa and 24 samples ]
# tax_table()   Taxonomy Table:    [ 1494 taxa by 7 taxonomic ranks ]
#  [1] " amiel1"       " amiel2"       " cpunta1"      " cpunta2"
#  [5] " pulque1"      " pulque2"      " amiel1subs1"  " amiel1subs2"
#  [9] " amiel1subs3"  " amiel2subs1"  " amiel2subs2"  " amiel2subs3"
# [13] " cpunta1subs1" " cpunta1subs2" " cpunta1subs3" " cpunta2subs1"
# [17] " cpunta2subs2" " cpunta2subs3" " pulque1subs1" " pulque1subs2"
# [21] " pulque1subs3" " pulque2subs1" " pulque2subs2" " pulque2subs3"
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 1494 taxa and 24 samples ]
# sample_data() Sample Data:       [ 24 samples by 2 sample variables ]
# tax_table()   Taxonomy Table:    [ 1494 taxa by 7 taxonomic ranks ]

# %%
tax_table(pulque)
write.csv(tax_table(pulque), "fungitax.txt")
# Out:
#      Kingdom Phylum        Class              Order
# 0    Fungi   Ascomycota    Saccharomycetes    Saccharomycetales
# 1    Fungi   Ascomycota    Saccharomycetes    Saccharomycetales
# 2    Fungi   unidentified  unidentified       unidentified
# 3    Fungi   unidentified  unidentified       unidentified
# 4    Fungi   Ascomycota    Eurotiomycetes     Eurotiales
# 5    Fungi   Ascomycota    Saccharomycetes    Saccharomycetales
# 6    Fungi   Ascomycota    Saccharomycetes    Saccharomycetales
# 7    Fungi   Ascomycota    Saccharomycetes    Saccharomycetales
# 8    Fungi   Ascomycota    Saccharomycetes    Saccharomycetales
# 9    Fungi   Ascomycota    Saccharomycetes    Saccharomycetales
# 10   Fungi   Ascomycota    Saccharomycetes    Saccharomycetales
# 11   Fungi   Ascomycota    Saccharomycetes    Saccharomycetales
# 12   Fungi   Ascomycota    Saccharomycetes    Saccharomycetales
# 13   Fungi   Ascomycota    Saccharomycetes    Saccharomycetales
# ...

# %%
p <- plot_richness(pulque, x="sample_type", color="sample_type", measures=c("Observed", "Chao1", "Shannon", "Simpson")) + geom_boxplot()+theme_light() + theme(axis.text.x=element_text(angle=90, hjust=1))
#p$data
a <-p$data
a

summary(a)
p
# Out:
#    id           sample_type samples       variable value     se
# 1  amiel1       amiel        amiel1       Observed 1000               NA
# 2  amiel2       amiel        amiel2       Observed  552               NA
# 3  cpunta1      cpunta       cpunta1      Observed   86               NA
# 4  cpunta2      cpunta       cpunta2      Observed   47               NA
# 5  pulque1      pulque       pulque1      Observed  130               NA
# 6  pulque2      pulque       pulque2      Observed   71               NA
# 7  amiel1subs1  amiel        amiel1subs1  Observed  544               NA
# 8  amiel1subs2  amiel        amiel1subs2  Observed  543               NA
# 9  amiel1subs3  amiel        amiel1subs3  Observed  550               NA
# 10 amiel2subs1  amiel        amiel2subs1  Observed  281               NA
# 11 amiel2subs2  amiel        amiel2subs2  Observed  305               NA
# 12 amiel2subs3  amiel        amiel2subs3  Observed  316               NA
# ...

# %%
samples_to_keep <- c(" amiel1", " amiel2", " pulque1", " pulque2", " cpunta1", " cpunta2")

# ?subset_samples
# pulque3 <- subset_samples(pulque, samples_to_keep)
# # pulque3 <- prune_samples(samples_to_keep)

pulque2 <- prune_samples(samples_to_keep
              , pulque
             )

pulque2

p <- plot_richness(pulque2, x="sample_type", color="sample_type", measures=c("Observed", "Chao1", "Shannon", "Simpson")) + geom_boxplot()+theme_light() + theme(axis.text.x=element_text(angle=90, hjust=1))
p
a <-p$data

summary(a)
write.table(a,"FUNGI_tabla_diversidad_alfa.csv")
for (ci in 1:ncol(df)) {
    write.csv(df[,ci], paste("col", ci, ".tsv", sep = ""))
}
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 1494 taxa and 6 samples ]
# sample_data() Sample Data:       [ 6 samples by 2 sample variables ]
# tax_table()   Taxonomy Table:    [ 1494 taxa by 7 taxonomic ranks ]
# Warning message:
# “Removed 18 rows containing missing values (geom_errorbar).”
#        id    sample_type   samples              variable     value
#  amiel1 :4   amiel :8    Length:24          Observed:6   Min.   :   0.8492
#  amiel2 :4   cpunta:8    Class :character   Chao1   :6   1st Qu.:   2.1620
#  cpunta1:4   pulque:8    Mode  :character   Shannon :6   Median :  24.8694
#  cpunta2:4                                  Simpson :6   Mean   : 158.0502
#  pulque1:4                                               3rd Qu.:  97.0000
#  pulque2:4                                               Max.   :1000.0000
#
#        se
#  Min.   :0.000000
#  1st Qu.:0.000000
#  Median :0.000000
#  Mean   :0.004507
#  3rd Qu.:0.006541
#  Max.   :0.018320
# ...

# %%
rarecurve(t(otu_table(biom_otu_tax)), step=100, label=T, col="blue")
# Out:
# plot without title

# %%
library("RColorBrewer")

GP1 <- pulque 

    tax_table(GP1) <- tax_table(GP1)[,1:6] #dejar sin especies la tabla
    x2 <- tax_glom(GP1, taxrank="Genus")
    

    phylum.sum = tapply(taxa_sums(x2), tax_table(x2)[, "Genus"], sum, na.rm = FALSE)
    top15phyla = names(sort(phylum.sum, TRUE))[1:22]
    gp1 = prune_taxa((tax_table(x2)[, "Genus"] %in% top15phyla), x2)    
    gp1 = transform_sample_counts(gp1, function(OTU) OTU/sum(OTU))
    gp1 <- phyloseq(otu_table(gp1), tax_table(pulque), sampledata)
   
    plot_heatmap(x2,"Jaccard", "bray", "sample_type", "Genus", low="#bebebe", high="#000000", na.value="white")
    mergeph1 = merge_samples(x2, "sample_type")
    mergeph1   
 plot_heatmap(mergeph1,"Jaccard", "bray", "sample_type", "Genus", low="#bebebe", high="#000000", na.value="white")
        
    plot_bar(gp1, fill="Genus") +  scale_fill_manual(values=rev(colorRampPalette(brewer.pal(12, "Paired"))(27))) +theme_bw() +theme(axis.text.x=element_text(angle=90, hjust=1, vjust=0.5))
# Out:
# Warning message in plot_heatmap(x2, "Jaccard", "bray", "sample_type", "Genus", low = "#bebebe", :
# “Attempt to access ordination coordinates for sample ordering failed.
# Using default sample ordering.”Warning message in plot_heatmap(x2, "Jaccard", "bray", "sample_type", "Genus", low = "#bebebe", :
# “Attempt to access ordination coordinates for feature/species/taxa/OTU ordering failed.
# Using default feature/species/taxa/OTU ordering.”Warning message:
# “Transformation introduced infinite values in discrete y-axis”
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 70 taxa and 3 samples ]
# sample_data() Sample Data:       [ 3 samples by 2 sample variables ]
# tax_table()   Taxonomy Table:    [ 70 taxa by 6 taxonomic ranks ]
# Warning message in plot_heatmap(mergeph1, "Jaccard", "bray", "sample_type", "Genus", :
# “Attempt to access ordination coordinates for sample ordering failed.
# ...

# %%
GP1 <- pulque

#     tax_table(GP1) <- tax_table(GP1)[,1:6] #dejar sin especies la tabla
    x2 <- tax_glom(GP1, taxrank="Species")
    

   
    mergeph1 = merge_samples(x2, "sample_type")
    mergeph1 = transform_sample_counts(mergeph1,function(x) x/sum(x))                              
    mergeph1   
                                  
#  plot_heatmap(mergeph1,"Jaccard", "bray", "sample_type", "Genus", low="#bebebe", high="#000000", na.value="white")
        
       #Correción a valores vacios en Género 
    
    ylabvec = as(tax_table(mergeph1)[,"Species"], "character")
names(ylabvec) <- taxa_names(mergeph1)
ylabvec[is.na(ylabvec)] <- ""
                                                                                                      
    t1 <- as.data.frame(colSums(otu_table(mergeph1))) #para ordenar x abundancia
head(t1)
# write.table(t, "vennupset.txt") 
t <-(tax_table(mergeph1)) #hago esto porque el melt sobre este objeto phyloseq no trabaja, creo que hay que usar psmelt para esto

 write.csv(t(otu_table(mergeph1)), "tmp_fungiotu.txt")
write.csv((tax_table(mergeph1)), "tmp_fungitax.txt")
                                                    
                                       
                                       
write.table(t, "fungivennupset.txt") 
t <- as.data.frame(read.table("fungivennupset.txt", header=T, row.names = 1))

# system("paste vennupset.txt taxvennupset.txt >coreupset.txt")

# read.table("coreupset.txt", header=T, sep="\t") 
t3 <- merge(t,t1, by=0, all=TRUE )
head(t3)
names(t3)[9] <-"abundance"

t4 <- t3[order(-t3$abundance),]
write.table(t4, "taxvennupset-lineas.txt")
 t5 <-   as.vector(t4$Row.names)
# t5
summary(t4)

plot_heatmap(mergeph1, "bray", taxa.order=rev(t5)) + scale_y_discrete(labels=ylabvec)  + theme_minimal () +
   scale_fill_gradient(low="#bebebe", high="#000000", na.value = "white", trans = "log2")  +
   theme(axis.text.x = element_text( angle = 90, hjust = 1),
         axis.text.y = element_text(size = 4))
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 121 taxa and 3 samples ]
# sample_data() Sample Data:       [ 3 samples by 2 sample variables ]
# tax_table()   Taxonomy Table:    [ 121 taxa by 7 taxonomic ranks ]
#    colSums(otu_table(mergeph1))
# 0  3.869486e-01
# 3  1.348712e-04
# 4  2.325365e-04
# 20 3.720584e-05
# 21 1.953307e-04
# 51 3.678728e-03
#   Row.names Kingdom Phylum        Class           Order
# 1 0         Fungi   Ascomycota    Saccharomycetes Saccharomycetales
# 2 1004      Fungi   Basidiomycota Tremellomycetes Filobasidiales
# 3 1011      Fungi   unidentified  unidentified    unidentified
# 4 1013      Fungi   Basidiomycota Tremellomycetes Filobasidiales
# 5 1014      Fungi   Ascomycota    Saccharomycetes Saccharomycetales
# 6 1015      Fungi   Ascomycota    Dothideomycetes Botryosphaeriales
#   Family             Genus         Species
# 1 Saccharomycetaceae Kluyveromyces Kluyveromyces_marxianus
# ...

# %%
GP1 <- pulque

#     tax_table(GP1) <- tax_table(GP1)[,1:6] #dejar sin especies la tabla
    x2 <- tax_glom(GP1, taxrank="Species")
    
#     phylum.sum = tapply(taxa_sums(x2), tax_table(x2)[, "Species"], sum, na.rm = FALSE)
#     top15phyla = names(sort(phylum.sum, TRUE))[1:30]
#     gp1 = prune_taxa((tax_table(x2)[, "Species"] %in% top15phyla), x2)   
   
    mergeph1 = merge_samples(x2, "sample_type")

#     mergeph1 = transform_sample_counts(mergeph1,function(x) x/sum(x))                              
    mergeph1   
                                       
                                       
write.csv(t(otu_table(mergeph1)), "tmp_fungiotu.txt")
write.csv((tax_table(mergeph1)), "tmp_fungitax.txt")
                                  
#  plot_heatmap(mergeph1,"Jaccard", "bray", "sample_type", "Genus", low="#bebebe", high="#000000", na.value="white")
        
       #Correción a valores vacios en Género 
    
    ylabvec = as(tax_table(mergeph1)[,"Species"], "character")
names(ylabvec) <- taxa_names(mergeph1)
ylabvec[is.na(ylabvec)] <- ""
                                                                                                      
    t1 <- as.data.frame(colSums(otu_table(mergeph1))) #para ordenar x abundancia
head(t1)
# write.table(t, "vennupset.txt") 
t <-(tax_table(mergeph1)) #hago esto porque el melt sobre este objeto phyloseq no trabaja, creo que hay que usar psmelt para esto

write.table(t, "taxvennupset.txt") 
t <- as.data.frame(read.table("taxvennupset.txt", header=T, row.names = 1))

# system("paste vennupset.txt taxvennupset.txt >coreupset.txt")

# read.table("coreupset.txt", header=T, sep="\t") 
t3 <- merge(t,t1, by=0, all=TRUE )
head(t3)
names(t3)[9] <-"abundance"
                                       

t4 <- t3[order(-t3$abundance),]
write.table(t4, "tmp_fungiheatmap.txt")
 t5 <-   as.vector(t4$Row.names)
                                       
# t5
summary(t4)

plot_heatmap(mergeph1, NULL, taxa.order=rev(t5)) + scale_y_discrete(labels=ylabvec)  + theme_minimal () +
   scale_fill_gradient(low="#bebebe", high="#000000", na.value = "white", trans = "log2")  +
   theme(axis.text.x = element_text( angle = 90, hjust = 1),
         axis.text.y = element_text(size = 5))
                                       

 ggsave("pulque_fungi_heatmap.pdf", width=21, height=27, units="cm")
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 121 taxa and 3 samples ]
# sample_data() Sample Data:       [ 3 samples by 2 sample variables ]
# tax_table()   Taxonomy Table:    [ 121 taxa by 7 taxonomic ranks ]
#    colSums(otu_table(mergeph1))
# 0  4770
# 3    29
# 4    50
# 20    8
# 21   42
# 51  791
#   Row.names Kingdom Phylum        Class           Order
# 1 0         Fungi   Ascomycota    Saccharomycetes Saccharomycetales
# 2 1004      Fungi   Basidiomycota Tremellomycetes Filobasidiales
# 3 1011      Fungi   unidentified  unidentified    unidentified
# 4 1013      Fungi   Basidiomycota Tremellomycetes Filobasidiales
# 5 1014      Fungi   Ascomycota    Saccharomycetes Saccharomycetales
# 6 1015      Fungi   Ascomycota    Dothideomycetes Botryosphaeriales
#   Family             Genus         Species
# 1 Saccharomycetaceae Kluyveromyces Kluyveromyces_marxianus
# 2 Filobasidiaceae    Cryptococcus  Cryptococcus_albidus
# ...

# %%
#para hacer el càlculo se obtienen las listas de OTUs por cada condición a comparar, luego usamos http://bioinformatics.psb.ugent.be/cgi-bin/liste/Venn/calculate_venn.htpl para armar los diagramas de Venn y las listas resultantes. 
merge1 = merge_samples(pulque, "sample_type")
write.table(t(otu_table(merge1)), "tmp")
df <-read.table("tmp", header=T, row.names = 1)
k <- which(df>=1, arr.ind=TRUE)
df[k] <- rownames(k)

write.table(df,"Venn_input_ITS.txt")
for (ci in 1:ncol(df)) {
    write.csv(df[,ci], paste("col", ci, ".tsv", sep = ""))
}

#cortar columnas 2 y 3, quitar 0s de Venn_input.txt 
#awk '{print $2"\t"$3}' Venn_input.txt | perl -pe 's/\"0\"//g;s/\"//g'

# %%
#hacer un heatmap solo con los OTUs core...(del punto anterior)
#este color picker está fantástico https://www.w3schools.com/colors/colors_picker.asp?color=80ced6


# physeqsubsetOTU <- subset_taxa(pulque, rownames(tax_table(pulque)) %in% c("664", "960", "1296", "936", "63", "1158", "951", "1438", "938", "1414", "1149", "1465", "1322", "1320", "178", "1432", "1470", "1321", "704", "1286", "1238", "833", "1", "947", "1458", "640", "1466", "793", "455", "1415", "966"))
# plot_heatmap(physeqsubsetOTU,"Jaccard", "bray", "sample_type", "Genus",low="#bebebe", high="#000000", na.value="white")

x2 <- physeqsubsetOTU
#OTUs únicos
x2
x2 = transform_sample_counts(x2, function(OTU) OTU/sum(OTU))
#    tax_table(x2) <- tax_table(x2)[,1:7] #dejar sin especies la tabla
x2 <- tax_glom(x2, taxrank="Species")
#Géneros
x2

#únicos pulque
mergeph1 = merge_samples(x2, "sample_type")
# mergeph1


# samples_to_keep <- c("cpunta")

# # ?subset_samples
# # pulque3 <- subset_samples(pulque, samples_to_keep)
# # # pulque3 <- prune_samples(samples_to_keep)

# mergeph1 <- prune_samples(samples_to_keep
#               , mergeph1
#              )
# plot_bar(mergeph1,"Species")

# plot_heatmap(mergeph1,"Jaccard", "bray", "sample_type", "Species",low="#bebebe", high="#000000", na.value="white")

ylabvec = as(tax_table(mergeph1)[,"Species"], "character")
names(ylabvec) <- taxa_names(mergeph1)
ylabvec[is.na(ylabvec)] <- ""
                                                                                                      
    t1 <- as.data.frame(colSums(otu_table(mergeph1))) #para ordenar x abundancia
head(t1)
# write.table(t, "vennupset.txt") 
t <-(tax_table(mergeph1)) #hago esto porque el melt sobre este objeto phyloseq no trabaja, creo que hay que usar psmelt para esto

write.table(t, "taxvennupset.txt") 
t <- as.data.frame(read.table("taxvennupset.txt", header=T, row.names = 1))

# system("paste vennupset.txt taxvennupset.txt >coreupset.txt")

# read.table("coreupset.txt", header=T, sep="\t") 
t3 <- merge(t,t1, by=0, all=TRUE )
head(t3)
names(t3)[9] <-"abundance"

t4 <- t3[order(-t3$abundance),]
write.table(t4, "taxvennupset-lineas.txt")
 t5 <-   as.vector(t4$Row.names)
# t5
summary(t4)

# samples_to_keep <- c("pulque")

# # ?subset_samples
# # pulque3 <- subset_samples(pulque, samples_to_keep)
# # # pulque3 <- prune_samples(samples_to_keep)

# mergeph1 <- prune_samples(samples_to_keep
#               , mergeph1
#              )
# plot_bar(mergeph1,"Species")

plot_heatmap(mergeph1,"NULL", taxa.order=rev(t5)) + scale_y_discrete(labels=ylabvec)  + theme_minimal () +
   scale_fill_gradient(low="#bebebe", high="#000000", na.value = "white", trans = "log2")  +
   theme(axis.text.x = element_text( angle = 90, hjust = 1),
         axis.text.y = element_text(size = 5))
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 31 taxa and 24 samples ]
# sample_data() Sample Data:       [ 24 samples by 2 sample variables ]
# tax_table()   Taxonomy Table:    [ 31 taxa by 7 taxonomic ranks ]
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 14 taxa and 24 samples ]
# sample_data() Sample Data:       [ 24 samples by 2 sample variables ]
# tax_table()   Taxonomy Table:    [ 14 taxa by 7 taxonomic ranks ]
#     colSums(otu_table(mergeph1))
# 1   0.2542213
# 63  2.1073488
# 178 0.1239526
# 455 0.2284779
# 664 0.1040307
# 833 1.3762075
#   Row.names Kingdom Phylum     Class           Order
# 1 1         Fungi   Ascomycota Saccharomycetes Saccharomycetales
# 2 1149      Fungi   Ascomycota Saccharomycetes Saccharomycetales
# 3 1158      Fungi   Ascomycota Saccharomycetes Saccharomycetales
# 4 1238      Fungi   Ascomycota Saccharomycetes Saccharomycetales
# ...

# %%
#los exclusivos del pulque:

physeqsubsetOTU <- subset_taxa(pulque, rownames(tax_table(pulque)) %in% c("1463", "1597", "129", "1444", "1038", "1319", "1653", "600", "46", "1409", "1006", "1646", "1601", "832", "1581", "1026", "50", "127", "1592", "45", "49", "628", "170", "122", "233", "774", "42", "954", "39", "792", "172", "1641", "1392", "1039", "743", "1408", "130", "945", "40", "1199", "171", "1591", "1412", "649", "1429", "1036", "1582", "1417", "1448", "619", "131", "1064", "618", "41", "132", "1578", "176", "125", "1655", "126", "1594", "1378", "44", "1098", "838", "43", "47", "1640", "1654", "1574", "1451", "1037", "175", "525", "1427", "1588", "785", "1648", "173", "128", "177", "124", "959", "1027", "731", "123"))
x2 <- physeqsubsetOTU
#OTUs únicos
x2

   tax_table(x2) <- tax_table(x2)[,1:7] #dejar sin especies la tabla
    x2 <- tax_glom(x2, taxrank="Species")
#Géneros
x2

#únicos pulque
mergeph1 = merge_samples(x2, "sample_type")
mergeph1
write.csv(t(otu_table(mergeph1)), "tmp_fungiotu.txt")
write.csv(t(tax_table(mergeph1)), "tmp_fungitax.txt")
    
    ylabvec = as(tax_table(mergeph1)[,"Species"], "character")
names(ylabvec) <- taxa_names(mergeph1)
ylabvec[is.na(ylabvec)] <- ""
                                                                                                      
    t1 <- as.data.frame(colSums(otu_table(mergeph1))) #para ordenar x abundancia
head(t1)
# write.table(t, "vennupset.txt") 
t <-(tax_table(mergeph1)) #hago esto porque el melt sobre este objeto phyloseq no trabaja, creo que hay que usar psmelt para esto

write.table(t, "taxvennupset.txt") 
t <- as.data.frame(read.table("taxvennupset.txt", header=T, row.names = 1))

# system("paste vennupset.txt taxvennupset.txt >coreupset.txt")

# read.table("coreupset.txt", header=T, sep="\t") 
t3 <- merge(t,t1, by=0, all=TRUE )
head(t3)
names(t3)[9] <-"abundance"

t4 <- t3[order(-t3$abundance),]
write.table(t4, "taxvennupset-lineas.txt")
 t5 <-   as.vector(t4$Row.names)
# t5
summary(t4)

samples_to_keep <- c("pulque")

# ?subset_samples
# pulque3 <- subset_samples(pulque, samples_to_keep)
# # pulque3 <- prune_samples(samples_to_keep)

mergeph1 <- prune_samples(samples_to_keep
              , mergeph1
             )
plot_bar(mergeph1,"Species")

plot_heatmap(mergeph1,"NULL", taxa.order=rev(t5)) + scale_y_discrete(labels=ylabvec)  + theme_minimal () +
   scale_fill_gradient(low="#bebebe", high="#000000", na.value = "white", trans = "log2")  +
   theme(axis.text.x = element_text( angle = 90, hjust = 1),
         axis.text.y = element_text(size = 5))
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 86 taxa and 24 samples ]
# sample_data() Sample Data:       [ 24 samples by 2 sample variables ]
# tax_table()   Taxonomy Table:    [ 86 taxa by 7 taxonomic ranks ]
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 20 taxa and 24 samples ]
# sample_data() Sample Data:       [ 24 samples by 2 sample variables ]
# tax_table()   Taxonomy Table:    [ 20 taxa by 7 taxonomic ranks ]
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 20 taxa and 3 samples ]
# sample_data() Sample Data:       [ 3 samples by 2 sample variables ]
# tax_table()   Taxonomy Table:    [ 20 taxa by 7 taxonomic ranks ]
#     colSums(otu_table(mergeph1))
# 41  18
# 233 79
# 525  2
# 600  4
# 618  4
# 619  3
#   Row.names Kingdom Phylum     Class           Order
# 1 1027      Fungi   Ascomycota Saccharomycetes Saccharomycetales
# ...

# %%
#los exclusivos del amiel:

"71", "972", "672", "1141", "1437", "211", "841", "689", "919", "760", "1049", "710", "389", "262", "224", "874", "872", "1150", "91", "52", "25", "192", "538", "430", "981", "989", "1367", "1406", "330", "138", "979", "773", "265", "698", "1493", "1271", "1210", "1439", "299", "558", "752", "1479", "552", "523", "824", "1375", "642", "392", "291", "738", "889", "146", "394", "500", "586", "800", "1347", "1531", "255", "31", "1552", "232", "1426", "1628", "167", "1553", "1555", "1634", "1377", "1270", "1554", "627", "1636", "115", "166", "844", "32", "716", "111", "1460", "1083", "120", "33", "117", "1561", "1550", "112", "1285", "1557", "1563", "730", "121", "658", "36", "965", "37", "231", "599", "781", "1043", "1443", "964", "791", "1635", "109", "116", "119", "1624", "1556", "1632", "1631", "1544", "34", "950", "1455", "38", "113", "168", "114", "118"))
physeqsubsetOTU

x2 <- physeqsubsetOTU
#OTUs únicos
x2

   
    x2 <- tax_glom(x2, taxrank="Species")
#Géneros
x2


mergeph1 = merge_samples(x2, "sample_type")
mergeph1


plot_bar(mergeph1,"Genus")

plot_heatmap(mergeph1,"Jaccard", "bray", "sample_type", "Species",low="#bebebe", high="#000000", na.value="white") +theme_light()

ggsave ("unicos_mezclados_fungi.pdf")
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 1405 taxa and 24 samples ]
# sample_data() Sample Data:       [ 24 samples by 2 sample variables ]
# tax_table()   Taxonomy Table:    [ 1405 taxa by 7 taxonomic ranks ]
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 1405 taxa and 24 samples ]
# sample_data() Sample Data:       [ 24 samples by 2 sample variables ]
# tax_table()   Taxonomy Table:    [ 1405 taxa by 7 taxonomic ranks ]
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 119 taxa and 24 samples ]
# sample_data() Sample Data:       [ 24 samples by 2 sample variables ]
# tax_table()   Taxonomy Table:    [ 119 taxa by 7 taxonomic ranks ]
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 119 taxa and 3 samples ]
# sample_data() Sample Data:       [ 3 samples by 2 sample variables ]
# tax_table()   Taxonomy Table:    [ 119 taxa by 7 taxonomic ranks ]
# ...

# %%
#Todo el dataset
physeqsubsetOTU <- pulque
physeqsubsetOTU

x2 <- physeqsubsetOTU
#OTUs únicos
x2

   tax_table(x2) <- tax_table(x2)[,1:6] #dejar sin especies la tabla
    x2 <- tax_glom(x2, taxrank="Genus")
#Géneros
x2


mergeph1 = merge_samples(x2, "sample_type")
mergeph1


plot_bar(mergeph1,"Genus")

plot_heatmap(mergeph1,"Jaccard", "bray", "sample_type", "Genus",low="#bebebe", high="#000000", na.value="white") +theme_light()

ggsave ("complete_dataset_fungi_heatmap.pdf")
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 1494 taxa and 24 samples ]
# sample_data() Sample Data:       [ 24 samples by 2 sample variables ]
# tax_table()   Taxonomy Table:    [ 1494 taxa by 7 taxonomic ranks ]
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 1494 taxa and 24 samples ]
# sample_data() Sample Data:       [ 24 samples by 2 sample variables ]
# tax_table()   Taxonomy Table:    [ 1494 taxa by 7 taxonomic ranks ]
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 70 taxa and 24 samples ]
# sample_data() Sample Data:       [ 24 samples by 2 sample variables ]
# tax_table()   Taxonomy Table:    [ 70 taxa by 6 taxonomic ranks ]
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 70 taxa and 3 samples ]
# sample_data() Sample Data:       [ 3 samples by 2 sample variables ]
# tax_table()   Taxonomy Table:    [ 70 taxa by 6 taxonomic ranks ]
# ...

# %%
#Todo el dataset hasta especie 
physeqsubsetOTU <- pulque
physeqsubsetOTU

x2 <- physeqsubsetOTU
#OTUs únicos
x2

   
    x2 <- tax_glom(x2, taxrank="Species")
#Géneros
x2


mergeph1 = merge_samples(x2, "sample_type")
mergeph1


a<- plot_bar(mergeph1,"Genus")
a
plot_heatmap(mergeph1,"Jaccard", "bray", "sample_type", "Species",low="#bebebe", high="#000000", na.value="white") +theme_light()

ggsave ("complete_dataset_fungi_heatmap2.pdf", height=40, width=30, units="cm")


write.table(a$data,"Fungi_allabundance.csv")
for (ci in 1:ncol(df)) {
    write.csv(df[,ci], paste("col", ci, ".tsv", sep = ""))
}
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 1494 taxa and 24 samples ]
# sample_data() Sample Data:       [ 24 samples by 2 sample variables ]
# tax_table()   Taxonomy Table:    [ 1494 taxa by 7 taxonomic ranks ]
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 1494 taxa and 24 samples ]
# sample_data() Sample Data:       [ 24 samples by 2 sample variables ]
# tax_table()   Taxonomy Table:    [ 1494 taxa by 7 taxonomic ranks ]
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 121 taxa and 24 samples ]
# sample_data() Sample Data:       [ 24 samples by 2 sample variables ]
# tax_table()   Taxonomy Table:    [ 121 taxa by 7 taxonomic ranks ]
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 121 taxa and 3 samples ]
# sample_data() Sample Data:       [ 3 samples by 2 sample variables ]
# tax_table()   Taxonomy Table:    [ 121 taxa by 7 taxonomic ranks ]
# ...

# %%
pulqueCAP.ORD <- ordinate(pulque, "CAP", "bray", ~ sample_type)
pulqueCAP.ORD

cap_plot <- plot_ordination(pulque, pulqueCAP.ORD, color="sample_type", axes =c(1,2)) + geom_point(aes(colour = sample_type), alpha=0.4, size=4) + geom_point(colour = "grey90", size=1.5) + theme_bw()

arrowmat <- vegan::scores(pulqueCAP.ORD, display="bp")
arrowdf <- data.frame(labels=rownames(arrowmat), arrowmat)

# Define the arrow aesthetic mapping
arrow_map <- aes(xend = CAP1, 
    yend = CAP2, 
    x = 0, 
    y = 0, 
    shape = NULL, 
    color = NULL, 
    label = labels)

label_map <- aes(x = 1.3 * CAP1, 
    y = 1.3 * CAP2, 
    shape = NULL, 
    color = NULL, 
    label = labels)

arrowhead = arrow(length = unit(0.02, "npc"))

cap_plot  + 
  geom_segment(
    mapping = arrow_map, 
    size = .5, 
    data = arrowdf, 
    color = "gray", 
    arrow = arrowhead
  ) + 
  geom_text(
    mapping = label_map, 
    size = 2,  
    data = arrowdf, 
    show.legend = FALSE
  )

an <- anova(pulqueCAP.ORD, permutations=9999)
an
ggsave("pulque_fungi_ordination.pdf", width=21, height=27, units="cm")
# Out:
# Call: capscale(formula = OTU ~ sample_type, data = data, distance =
# distance)
#
#                  Inertia Proportion Rank
# Total          7.2423502  1.0000000
# Constrained    4.0838333  0.5638823    2
# Unconstrained  3.1622780  0.4366370   20
# Imaginary     -0.0037610 -0.0005193    2
# Inertia is squared Bray distance
# Species scores projected from ‘OTU’
#
# Eigenvalues for constrained axes:
#   CAP1   CAP2
# 3.0135 1.0703
#
# Eigenvalues for unconstrained axes:
#   MDS1   MDS2   MDS3   MDS4   MDS5   MDS6   MDS7   MDS8
# 1.1165 0.6702 0.5210 0.3176 0.2559 0.0988 0.0421 0.0362
# (Showing 8 of 20 unconstrained eigenvalues)
# Warning message:
# “Ignoring unknown aesthetics: label”
#          Df SumOfSqs F        Pr(>F)
# Model     2 4.083833 13.55992 1e-04
# Residual 21 3.162278       NA    NA
# plot without title

# %%
library(DESeq2)
library(phyloseq)
library(plyr)
library(RColorBrewer)

#pulque-cpunta
pulque_sig = pulque
pulque_sig=subset_samples(pulque, sample_type != "amiel")
sample_data(pulque_sig)$var = factor (get_variable(pulque_sig, "sample_type") %in% c("pulque"))
pulque_sig
obj1deseq = phyloseq_to_deseq2(pulque_sig, ~sample_type)


gm_mean = function(x, na.rm=TRUE){
  exp(sum(log(x[x > 0]), na.rm=na.rm) / length(x))
}

geoMeans = apply(counts(obj1deseq), 1, gm_mean)
obj1deseq = estimateSizeFactors(obj1deseq, geoMeans = geoMeans)

##adición de la viñeta para el error de la media de 0s
obj1deseq = DESeq(obj1deseq, fitType="local")


res = results(obj1deseq, cooksCutoff = FALSE)
# quick explanation of Cook's distance: it measures within each gene, for each sample, how removing that sample would change the LFCs (all of the coefficients implied by the design and estimated by DESeq2). So if you have e.g. 3 samples vs 2 samples, and the counts for a gene are [10,10,10] vs [15, 1000], you can see how the Cook's distance will be high for the two samples. Removing either one changes the LFC for the comparison of the two groups. However, if it were [10,10,10] vs [50,50], the two samples "support" each other, such that removing one doesn't change the LFC at all. Hence, we find Cook's to be useful for identifying outliers.
alpha = 0.0001
sigtab = res[which(res$padj < alpha), ]
sigtab = cbind(as(sigtab, "data.frame"), as(tax_table(pulque_sig)[rownames(sigtab), ], "matrix"))
# Phylum order
x = tapply(sigtab$log2FoldChange, sigtab$Phylum, function(x) max(x))
x = sort(x, TRUE)
sigtab$Phylum = factor(as.character(sigtab$Phylum), levels=names(x))
# Genus order
x = tapply(sigtab$log2FoldChange, sigtab$Species, function(x) max(x))
x = sort(x, TRUE)
sigtab$Genus = factor(as.character(sigtab$Species), levels=names(x))

ggplot(sigtab, aes(x=Genus, y=log2FoldChange, color=Order)) + scale_color_manual(values=colorRampPalette(brewer.pal(8,"Dark2"))(20))+geom_point(size=3)+theme_light() +theme(axis.text.x = element_text(angle = -90, hjust = 0, vjust=0.5))
#sigtab
#ggsave ("torniquete_pasamanos_SIG.pdf", width=30, height=15, units="cm")
  write.table(sigtab,"Fungi_pulque-cpuntaOR.csv")
for (ci in 1:ncol(df)) {
    write.csv(df[,ci], paste("col", ci, ".tsv", sep = ""))
}
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 1494 taxa and 16 samples ]
# sample_data() Sample Data:       [ 16 samples by 3 sample variables ]
# tax_table()   Taxonomy Table:    [ 1494 taxa by 7 taxonomic ranks ]
# converting counts to integer mode
# using pre-existing size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Error in 1:ncol(df): argument of length 0
# Traceback:
# plot without title

# %%
#pulque-aguamiel
pulque_sig = pulque
pulque_sig=subset_samples(pulque, sample_type != "cpunta")
sample_data(pulque_sig)$var = factor (get_variable(pulque_sig, "sample_type") %in% c("pulque"))
pulque_sig
obj1deseq = phyloseq_to_deseq2(pulque_sig, ~sample_type)


gm_mean = function(x, na.rm=TRUE){
  exp(sum(log(x[x > 0]), na.rm=na.rm) / length(x))
}

geoMeans = apply(counts(obj1deseq), 1, gm_mean)
obj1deseq = estimateSizeFactors(obj1deseq, geoMeans = geoMeans)

##adición de la viñeta para el error de la media de 0s
obj1deseq = DESeq(obj1deseq, fitType="local")


res = results(obj1deseq, cooksCutoff = FALSE)
# quick explanation of Cook's distance: it measures within each gene, for each sample, how removing that sample would change the LFCs (all of the coefficients implied by the design and estimated by DESeq2). So if you have e.g. 3 samples vs 2 samples, and the counts for a gene are [10,10,10] vs [15, 1000], you can see how the Cook's distance will be high for the two samples. Removing either one changes the LFC for the comparison of the two groups. However, if it were [10,10,10] vs [50,50], the two samples "support" each other, such that removing one doesn't change the LFC at all. Hence, we find Cook's to be useful for identifying outliers.
alpha = 0.0001
sigtab = res[which(res$padj < alpha), ]
sigtab = cbind(as(sigtab, "data.frame"), as(tax_table(pulque_sig)[rownames(sigtab), ], "matrix"))
# Phylum order
x = tapply(sigtab$log2FoldChange, sigtab$Phylum, function(x) max(x))
x = sort(x, TRUE)
sigtab$Phylum = factor(as.character(sigtab$Phylum), levels=names(x))
# Genus order
x = tapply(sigtab$log2FoldChange, sigtab$Species, function(x) max(x))
x = sort(x, TRUE)
sigtab$Genus = factor(as.character(sigtab$Species), levels=names(x))

ggplot(sigtab, aes(x=Genus, y=log2FoldChange, color=Order)) + scale_color_manual(values=colorRampPalette(brewer.pal(8,"Dark2"))(20))+geom_point(size=3)+theme_light() +theme(axis.text.x = element_text(angle = -90, hjust = 0, vjust=0.5))
#sigtab
#ggsave ("torniquete_pasamanos_SIG.pdf", width=30, height=15, units="cm")
  write.table(sigtab,"Fungi_pulque-amiel_OR.csv")
for (ci in 1:ncol(df)) {
    write.csv(df[,ci], paste("col", ci, ".tsv", sep = ""))
}
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 1494 taxa and 16 samples ]
# sample_data() Sample Data:       [ 16 samples by 3 sample variables ]
# tax_table()   Taxonomy Table:    [ 1494 taxa by 7 taxonomic ranks ]
# converting counts to integer mode
# using pre-existing size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Error in 1:ncol(df): argument of length 0
# Traceback:
# plot without title

# %%
#amiel-cpunta
pulque_sig = pulque
pulque_sig=subset_samples(pulque, sample_type != "pulque")
sample_data(pulque_sig)$var = factor (get_variable(pulque_sig, "sample_type") %in% c("amiel"))
pulque_sig
obj1deseq = phyloseq_to_deseq2(pulque_sig, ~sample_type)


gm_mean = function(x, na.rm=TRUE){
  exp(sum(log(x[x > 0]), na.rm=na.rm) / length(x))
}

geoMeans = apply(counts(obj1deseq), 1, gm_mean)
obj1deseq = estimateSizeFactors(obj1deseq, geoMeans = geoMeans)

##adición de la viñeta para el error de la media de 0s
obj1deseq = DESeq(obj1deseq, fitType="local")


res = results(obj1deseq, cooksCutoff = FALSE)
# quick explanation of Cook's distance: it measures within each gene, for each sample, how removing that sample would change the LFCs (all of the coefficients implied by the design and estimated by DESeq2). So if you have e.g. 3 samples vs 2 samples, and the counts for a gene are [10,10,10] vs [15, 1000], you can see how the Cook's distance will be high for the two samples. Removing either one changes the LFC for the comparison of the two groups. However, if it were [10,10,10] vs [50,50], the two samples "support" each other, such that removing one doesn't change the LFC at all. Hence, we find Cook's to be useful for identifying outliers.
alpha = 0.0001
sigtab = res[which(res$padj < alpha), ]
sigtab = cbind(as(sigtab, "data.frame"), as(tax_table(pulque_sig)[rownames(sigtab), ], "matrix"))
# Phylum order
x = tapply(sigtab$log2FoldChange, sigtab$Phylum, function(x) max(x))
x = sort(x, TRUE)
sigtab$Phylum = factor(as.character(sigtab$Phylum), levels=names(x))
# Genus order
x = tapply(sigtab$log2FoldChange, sigtab$Species, function(x) max(x))
x = sort(x, TRUE)
sigtab$Genus = factor(as.character(sigtab$Species), levels=names(x))

ggplot(sigtab, aes(x=Genus, y=log2FoldChange, color=Order)) + scale_color_manual(values=colorRampPalette(brewer.pal(8,"Dark2"))(30))+geom_point(size=3)+theme_light() +theme(axis.text.x = element_text(angle = -90, hjust = 0, vjust=0.5))
#sigtab
#ggsave ("torniquete_pasamanos_SIG.pdf", width=30, height=15, units="cm")
  write.table(sigtab,"Fungi_amiel-cpunta_OR.csv")
for (ci in 1:ncol(df)) {
    write.csv(df[,ci], paste("col", ci, ".tsv", sep = ""))
}
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 1494 taxa and 16 samples ]
# sample_data() Sample Data:       [ 16 samples by 3 sample variables ]
# tax_table()   Taxonomy Table:    [ 1494 taxa by 7 taxonomic ranks ]
# converting counts to integer mode
# using pre-existing size factors
# estimating dispersions
# gene-wise dispersion estimates
# mean-dispersion relationship
# final dispersion estimates
# fitting model and testing
# Error in 1:ncol(df): argument of length 0
# Traceback:
# plot without title
